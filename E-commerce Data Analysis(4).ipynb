# %% [markdown]
# # E-Commerce Data Analysis using PySpark

# %% [markdown]
# ## Import necessary libraries

# %%
import os

# %%
import findspark

# %% [markdown]
# ## Set up OS environment

# %%
os.environ["JAVA_HOME"]="/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"]="/home/niharika/spark-3.2.0-bin-hadoop3.2"

# %%
os.environ["HADOOP_HOME"]="/home/niharika/hadoop-3.3.1"

# %% [markdown]
# ## Initialize spark session

# %%
findspark.init()
from pyspark.sql import SparkSession
spark=SparkSession.builder.master("local[*]").getOrCreate()
# Out:
# 22/01/21 17:40:02 WARN Utils: Your hostname, niharika-VirtualBox resolves to a loopback address: 127.0.1.1; using 10.0.2.15 instead (on interface enp0s3)
# 22/01/21 17:40:02 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/01/21 17:40:03 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df = spark.read.csv("hdfs://localhost:9000/user/input/data.csv", header=True)

# %%
df.createOrReplaceTempView("ecom")

# %% [markdown]
# ## Display csv file in the form of SQL table

# %%
spark.sql("select * from ecom").show()
# Out:
# +---------+---------+--------------------+--------+--------------+---------+----------+--------------+
# |InvoiceNo|StockCode|         Description|Quantity|   InvoiceDate|UnitPrice|CustomerID|       Country|
# +---------+---------+--------------------+--------+--------------+---------+----------+--------------+
# |   536365|   85123A|WHITE HANGING HEA...|       6|12/1/2010 8:26|     2.55|     17850|United Kingdom|
# |   536365|    71053| WHITE METAL LANTERN|       6|12/1/2010 8:26|     3.39|     17850|United Kingdom|
# |   536365|   84406B|CREAM CUPID HEART...|       8|12/1/2010 8:26|     2.75|     17850|United Kingdom|
# |   536365|   84029G|KNITTED UNION FLA...|       6|12/1/2010 8:26|     3.39|     17850|United Kingdom|
# |   536365|   84029E|RED WOOLLY HOTTIE...|       6|12/1/2010 8:26|     3.39|     17850|United Kingdom|
# |   536365|    22752|SET 7 BABUSHKA NE...|       2|12/1/2010 8:26|     7.65|     17850|United Kingdom|
# |   536365|    21730|GLASS STAR FROSTE...|       6|12/1/2010 8:26|     4.25|     17850|United Kingdom|
# |   536366|    22633|HAND WARMER UNION...|       6|12/1/2010 8:28|     1.85|     17850|United Kingdom|
# |   536366|    22632|HAND WARMER RED P...|       6|12/1/2010 8:28|     1.85|     17850|United Kingdom|
# |   536367|    84879|ASSORTED COLOUR B...|      32|12/1/2010 8:34|     1.69|     13047|United Kingdom|
# |   536367|    22745|POPPY'S PLAYHOUSE...|       6|12/1/2010 8:34|      2.1|     13047|United Kingdom|
# |   536367|    22748|POPPY'S PLAYHOUSE...|       6|12/1/2010 8:34|      2.1|     13047|United Kingdom|
# |   536367|    22749|FELTCRAFT PRINCES...|       8|12/1/2010 8:34|     3.75|     13047|United Kingdom|
# |   536367|    22310|IVORY KNITTED MUG...|       6|12/1/2010 8:34|     1.65|     13047|United Kingdom|
# |   536367|    84969|BOX OF 6 ASSORTED...|       6|12/1/2010 8:34|     4.25|     13047|United Kingdom|
# |   536367|    22623|BOX OF VINTAGE JI...|       3|12/1/2010 8:34|     4.95|     13047|United Kingdom|
# |   536367|    22622|BOX OF VINTAGE AL...|       2|12/1/2010 8:34|     9.95|     13047|United Kingdom|
# |   536367|    21754|HOME BUILDING BLO...|       3|12/1/2010 8:34|     5.95|     13047|United Kingdom|
# |   536367|    21755|LOVE BUILDING BLO...|       3|12/1/2010 8:34|     5.95|     13047|United Kingdom|
# |   536367|    21777|RECIPE BOX WITH M...|       4|12/1/2010 8:34|     7.95|     13047|United Kingdom|
# +---------+---------+--------------------+--------+--------------+---------+----------+--------------+
# only showing top 20 rows

# %% [markdown]
# ## Total number of records in e-commerce table

# %%
spark.sql("select count(*) from ecom").show()
# Out:
# [Stage 2:>                                                          (0 + 2) / 2]
# +--------+
# |count(1)|
# +--------+
# |  541909|
# +--------+

# %%
from pyspark.sql.functions import isnan, when, count, col
df.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in df.columns]).show()
# Out:
# [Stage 5:=============================>                             (1 + 1) / 2]
# +---------+---------+-----------+--------+-----------+---------+----------+-------+
# |InvoiceNo|StockCode|Description|Quantity|InvoiceDate|UnitPrice|CustomerID|Country|
# +---------+---------+-----------+--------+-----------+---------+----------+-------+
# |        0|        0|       1454|       0|          0|        0|    135080|      0|
# +---------+---------+-----------+--------+-----------+---------+----------+-------+

# %%
df.na.fill(0).show()
# Out:
# +---------+---------+--------------------+--------+--------------+---------+----------+--------------+
# |InvoiceNo|StockCode|         Description|Quantity|   InvoiceDate|UnitPrice|CustomerID|       Country|
# +---------+---------+--------------------+--------+--------------+---------+----------+--------------+
# |   536365|   85123A|WHITE HANGING HEA...|       6|12/1/2010 8:26|     2.55|     17850|United Kingdom|
# |   536365|    71053| WHITE METAL LANTERN|       6|12/1/2010 8:26|     3.39|     17850|United Kingdom|
# |   536365|   84406B|CREAM CUPID HEART...|       8|12/1/2010 8:26|     2.75|     17850|United Kingdom|
# |   536365|   84029G|KNITTED UNION FLA...|       6|12/1/2010 8:26|     3.39|     17850|United Kingdom|
# |   536365|   84029E|RED WOOLLY HOTTIE...|       6|12/1/2010 8:26|     3.39|     17850|United Kingdom|
# |   536365|    22752|SET 7 BABUSHKA NE...|       2|12/1/2010 8:26|     7.65|     17850|United Kingdom|
# |   536365|    21730|GLASS STAR FROSTE...|       6|12/1/2010 8:26|     4.25|     17850|United Kingdom|
# |   536366|    22633|HAND WARMER UNION...|       6|12/1/2010 8:28|     1.85|     17850|United Kingdom|
# |   536366|    22632|HAND WARMER RED P...|       6|12/1/2010 8:28|     1.85|     17850|United Kingdom|
# |   536367|    84879|ASSORTED COLOUR B...|      32|12/1/2010 8:34|     1.69|     13047|United Kingdom|
# |   536367|    22745|POPPY'S PLAYHOUSE...|       6|12/1/2010 8:34|      2.1|     13047|United Kingdom|
# |   536367|    22748|POPPY'S PLAYHOUSE...|       6|12/1/2010 8:34|      2.1|     13047|United Kingdom|
# |   536367|    22749|FELTCRAFT PRINCES...|       8|12/1/2010 8:34|     3.75|     13047|United Kingdom|
# |   536367|    22310|IVORY KNITTED MUG...|       6|12/1/2010 8:34|     1.65|     13047|United Kingdom|
# |   536367|    84969|BOX OF 6 ASSORTED...|       6|12/1/2010 8:34|     4.25|     13047|United Kingdom|
# |   536367|    22623|BOX OF VINTAGE JI...|       3|12/1/2010 8:34|     4.95|     13047|United Kingdom|
# |   536367|    22622|BOX OF VINTAGE AL...|       2|12/1/2010 8:34|     9.95|     13047|United Kingdom|
# |   536367|    21754|HOME BUILDING BLO...|       3|12/1/2010 8:34|     5.95|     13047|United Kingdom|
# |   536367|    21755|LOVE BUILDING BLO...|       3|12/1/2010 8:34|     5.95|     13047|United Kingdom|
# |   536367|    21777|RECIPE BOX WITH M...|       4|12/1/2010 8:34|     7.95|     13047|United Kingdom|
# +---------+---------+--------------------+--------+--------------+---------+----------+--------------+
# only showing top 20 rows

# %%
spark.sql("select count(*) from ecom").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |  541909|
# +--------+

# %%
spark.sql("select * from ecom").show()
# Out:
# +---------+---------+--------------------+--------+--------------+---------+----------+--------------+
# |InvoiceNo|StockCode|         Description|Quantity|   InvoiceDate|UnitPrice|CustomerID|       Country|
# +---------+---------+--------------------+--------+--------------+---------+----------+--------------+
# |   536365|   85123A|WHITE HANGING HEA...|       6|12/1/2010 8:26|     2.55|     17850|United Kingdom|
# |   536365|    71053| WHITE METAL LANTERN|       6|12/1/2010 8:26|     3.39|     17850|United Kingdom|
# |   536365|   84406B|CREAM CUPID HEART...|       8|12/1/2010 8:26|     2.75|     17850|United Kingdom|
# |   536365|   84029G|KNITTED UNION FLA...|       6|12/1/2010 8:26|     3.39|     17850|United Kingdom|
# |   536365|   84029E|RED WOOLLY HOTTIE...|       6|12/1/2010 8:26|     3.39|     17850|United Kingdom|
# |   536365|    22752|SET 7 BABUSHKA NE...|       2|12/1/2010 8:26|     7.65|     17850|United Kingdom|
# |   536365|    21730|GLASS STAR FROSTE...|       6|12/1/2010 8:26|     4.25|     17850|United Kingdom|
# |   536366|    22633|HAND WARMER UNION...|       6|12/1/2010 8:28|     1.85|     17850|United Kingdom|
# |   536366|    22632|HAND WARMER RED P...|       6|12/1/2010 8:28|     1.85|     17850|United Kingdom|
# |   536367|    84879|ASSORTED COLOUR B...|      32|12/1/2010 8:34|     1.69|     13047|United Kingdom|
# |   536367|    22745|POPPY'S PLAYHOUSE...|       6|12/1/2010 8:34|      2.1|     13047|United Kingdom|
# |   536367|    22748|POPPY'S PLAYHOUSE...|       6|12/1/2010 8:34|      2.1|     13047|United Kingdom|
# |   536367|    22749|FELTCRAFT PRINCES...|       8|12/1/2010 8:34|     3.75|     13047|United Kingdom|
# |   536367|    22310|IVORY KNITTED MUG...|       6|12/1/2010 8:34|     1.65|     13047|United Kingdom|
# |   536367|    84969|BOX OF 6 ASSORTED...|       6|12/1/2010 8:34|     4.25|     13047|United Kingdom|
# |   536367|    22623|BOX OF VINTAGE JI...|       3|12/1/2010 8:34|     4.95|     13047|United Kingdom|
# |   536367|    22622|BOX OF VINTAGE AL...|       2|12/1/2010 8:34|     9.95|     13047|United Kingdom|
# |   536367|    21754|HOME BUILDING BLO...|       3|12/1/2010 8:34|     5.95|     13047|United Kingdom|
# |   536367|    21755|LOVE BUILDING BLO...|       3|12/1/2010 8:34|     5.95|     13047|United Kingdom|
# |   536367|    21777|RECIPE BOX WITH M...|       4|12/1/2010 8:34|     7.95|     13047|United Kingdom|
# +---------+---------+--------------------+--------+--------------+---------+----------+--------------+
# only showing top 20 rows

# %% [markdown]
# ## Co relation between columns

# %%
from pyspark.sql.functions import *
df1=df.groupBy("Description") \
      .agg({"Quantity":"sum"}).select("Description",col("sum(Quantity)")).alias("total_quantity")

# %% [markdown]
# ## Relation between Products description and quantity of products sold

# %%
df1.show()
# Out:
# [Stage 200:============================>                            (1 + 1) / 2]
# +--------------------+-------------+
# |         Description|sum(Quantity)|
# +--------------------+-------------+
# |10 COLOUR SPACEBO...|       6392.0|
# |SET/10 BLUE POLKA...|       3966.0|
# |POTTING SHED SOW ...|          2.0|
# |PAPERWEIGHT KINGS...|        162.0|
# |WOVEN BERRIES CUS...|        162.0|
# |WHITE/PINK MINI C...|         10.0|
# |SET/3 RED GINGHAM...|       2999.0|
# |MAGNETS PACK OF 4...|       1311.0|
# |WHITE CHRYSANTHEM...|         53.0|
# |WHITE FRANGIPANI ...|         33.0|
# |SILVER FABRIC MIRROR|        458.0|
# |PINK  HONEYCOMB P...|        489.0|
# |PINK BOUDOIR T-LI...|         12.0|
# | BLACK CHERRY LIGHTS|          0.0|
# |GLASS CAKE COVER ...|          0.0|
# |DECORATION SITTIN...|       1441.0|
# |ANTIQUE MID BLUE ...|          5.0|
# |IVORY ENCHANTED F...|        512.0|
# |ANTIQUE SILVER TE...|       4539.0|
# |BLUE FELT HANGING...|         16.0|
# +--------------------+-------------+
# only showing top 20 rows
# 22/01/21 22:55:42 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 3818854 ms exceeds timeout 120000 ms
# 22/01/21 22:55:43 WARN SparkContext: Killing executors is not supported by current scheduler.

# %%
df.groupBy("Description") \
  .agg(sum("Quantity").alias("Total_Quantity")) \
  .sort(col("Total_Quantity").asc()) \
  .show()
# Out:
# [Stage 16:=============================>                            (1 + 1) / 2]
# +--------------------+--------------+
# |         Description|Total_Quantity|
# +--------------------+--------------+
# |printing smudges/...|      -19200.0|
# |Unsaleable, destr...|      -15644.0|
# |                null|      -13609.0|
# |               check|      -12030.0|
# |Printing smudges/...|       -9058.0|
# |             Damaged|       -7540.0|
# |          throw away|       -5368.0|
# |             damages|       -4338.0|
# |incorrect stock e...|       -4320.0|
# |         thrown away|       -4110.0|
# |wrongly marked. 2...|       -3100.0|
# |         damages wax|       -2844.0|
# |mouldy, thrown away.|       -2600.0|
# |thrown away-can't...|       -2472.0|
# |sold as set on do...|       -2393.0|
# |   Thrown away-rusty|       -2376.0|
# |            ?missing|       -2331.0|
# |                  ??|       -1849.0|
# | mouldy, unsaleable.|       -1681.0|
# |             damaged|       -1632.0|
# +--------------------+--------------+
# only showing top 20 rows

# %% [markdown]
# #### The above table shows negative quantity values as these products were not sold/damaged

# %%
df.groupBy("Description") \
  .agg(sum("Quantity").alias("Total_Quantity")) \
  .sort(col("Total_Quantity").desc()) \
  .show()
# Out:
# [Stage 19:=============================>                            (1 + 1) / 2]
# +--------------------+--------------+
# |         Description|Total_Quantity|
# +--------------------+--------------+
# |WORLD WAR 2 GLIDE...|       53847.0|
# |JUMBO BAG RED RET...|       47363.0|
# |ASSORTED COLOUR B...|       36381.0|
# |      POPCORN HOLDER|       36334.0|
# |PACK OF 72 RETROS...|       36039.0|
# |WHITE HANGING HEA...|       35317.0|
# |  RABBIT NIGHT LIGHT|       30680.0|
# |MINI PAINT SET VI...|       26437.0|
# |PACK OF 12 LONDON...|       26315.0|
# |PACK OF 60 PINK P...|       24753.0|
# |VICTORIAN GLASS H...|       23854.0|
# |ASSORTED COLOURS ...|       23082.0|
# | BROCADE RING PURSE |       23053.0|
# |RED  HARMONICA IN...|       21866.0|
# |JUMBO BAG PINK PO...|       21009.0|
# |SMALL POPCORN HOLDER|       20116.0|
# |PAPER CHAIN KIT 5...|       18902.0|
# |LUNCH BAG RED RET...|       18779.0|
# |60 TEATIME FAIRY ...|       18040.0|
# |       PARTY BUNTING|       18022.0|
# +--------------------+--------------+
# only showing top 20 rows

# %% [markdown]
# #### The above table shows the description of the maximum product sold i.e, World war 2 gliders asstd designs followed by Jumbo bag red retrospot.

# %% [markdown]
# ### Relation between products description and quantity wrt Country

# %%
df.groupBy("Description","Country") \
  .agg(sum("Quantity").alias("Total_Quantity")) \
  .show()
# Out:
# [Stage 22:=============================>                            (1 + 1) / 2]
# +--------------------+--------------+--------------+
# |         Description|       Country|Total_Quantity|
# +--------------------+--------------+--------------+
# |HOMEMADE JAM SCEN...|United Kingdom|       10282.0|
# |FAMILY PHOTO FRAM...|United Kingdom|         807.0|
# |GREEN DRAWER KNOB...|United Kingdom|        1919.0|
# |ASSORTED COLOUR L...|       Germany|          48.0|
# |KITTENS DESIGN FL...|United Kingdom|         289.0|
# |      FUNKY DIVA PEN|United Kingdom|        7236.0|
# |ANT COPPER RED BO...|United Kingdom|          24.0|
# |MIRRORED WALL ART...|United Kingdom|          68.0|
# |SKULLS AND CROSSB...|United Kingdom|        5500.0|
# |POLYESTER FILLER ...|United Kingdom|         103.0|
# |CERAMIC CAKE BOWL...|United Kingdom|         510.0|
# |  KIDS RAIN MAC BLUE|United Kingdom|         867.0|
# |   WRAP GREEN PEARS |          EIRE|          50.0|
# | HAPPY STENCIL CRAFT|United Kingdom|        2523.0|
# |IVORY KITCHEN SCALES|       Germany|          66.0|
# |GUMBALL MAGAZINE ...|       Germany|          15.0|
# |"RECORD FRAME 7""...|        France|          24.0|
# |WHITE BAMBOO RIBS...|         Spain|           1.0|
# |IVORY SHELL HEART...|United Kingdom|          10.0|
# |SET OF 6 T-LIGHTS...|       Germany|          18.0|
# +--------------------+--------------+--------------+
# only showing top 20 rows

# %%
df.groupBy("Description","Country") \
  .agg(sum("Quantity").alias("Total_Quantity")) \
  .sort(col("Total_Quantity").desc()) \
  .show()
# Out:
# [Stage 25:>                                                         (0 + 2) / 2]
# +--------------------+--------------+--------------+
# |         Description|       Country|Total_Quantity|
# +--------------------+--------------+--------------+
# |WORLD WAR 2 GLIDE...|United Kingdom|       48326.0|
# |JUMBO BAG RED RET...|United Kingdom|       43167.0|
# |      POPCORN HOLDER|United Kingdom|       34365.0|
# |ASSORTED COLOUR B...|United Kingdom|       33679.0|
# |WHITE HANGING HEA...|United Kingdom|       33193.0|
# |PACK OF 12 LONDON...|United Kingdom|       25307.0|
# |PACK OF 72 RETROS...|United Kingdom|       24702.0|
# |VICTORIAN GLASS H...|United Kingdom|       23242.0|
# | BROCADE RING PURSE |United Kingdom|       22801.0|
# |ASSORTED COLOURS ...|United Kingdom|       20322.0|
# |PACK OF 60 PINK P...|United Kingdom|       20288.0|
# |JUMBO BAG PINK PO...|United Kingdom|       18936.0|
# |SMALL POPCORN HOLDER|United Kingdom|       18563.0|
# |PAPER CHAIN KIT 5...|United Kingdom|       18197.0|
# |RED  HARMONICA IN...|United Kingdom|       17754.0|
# |HEART OF WICKER S...|United Kingdom|       17394.0|
# |       PARTY BUNTING|United Kingdom|       16709.0|
# |JUMBO BAG STRAWBERRY|United Kingdom|       16056.0|
# |CHARLOTTE BAG SUK...|United Kingdom|       15974.0|
# |COLOUR GLASS T-LI...|United Kingdom|       15400.0|
# +--------------------+--------------+--------------+
# only showing top 20 rows

# %% [markdown]
# #### From the above table we can say that maximum products are sold to people living in the United Kingdom.Products like World war 2 gliders asstd designs,Jumbo bag red retrospot, Popcorn holder and so on..

# %%
df.groupBy("Description","Country") \
  .agg(sum("Quantity").alias("Total_Quantity")) \
  .sort(col("Total_Quantity").asc()) \
  .show()
# Out:
# [Stage 28:>                                                         (0 + 2) / 2]
# +--------------------+--------------+--------------+
# |         Description|       Country|Total_Quantity|
# +--------------------+--------------+--------------+
# |printing smudges/...|United Kingdom|      -19200.0|
# |Unsaleable, destr...|United Kingdom|      -15644.0|
# |                null|United Kingdom|      -13609.0|
# |               check|United Kingdom|      -12030.0|
# |Printing smudges/...|United Kingdom|       -9058.0|
# |             Damaged|United Kingdom|       -7540.0|
# |          throw away|United Kingdom|       -5368.0|
# |             damages|United Kingdom|       -4338.0|
# |incorrect stock e...|United Kingdom|       -4320.0|
# |         thrown away|United Kingdom|       -4110.0|
# |wrongly marked. 2...|United Kingdom|       -3100.0|
# |         damages wax|United Kingdom|       -2844.0|
# |mouldy, thrown away.|United Kingdom|       -2600.0|
# |thrown away-can't...|United Kingdom|       -2472.0|
# |sold as set on do...|United Kingdom|       -2393.0|
# |   Thrown away-rusty|United Kingdom|       -2376.0|
# |            ?missing|United Kingdom|       -2331.0|
# |                  ??|United Kingdom|       -1849.0|
# | mouldy, unsaleable.|United Kingdom|       -1681.0|
# |             damaged|United Kingdom|       -1632.0|
# +--------------------+--------------+--------------+
# only showing top 20 rows

# %% [markdown]
# ### Relation between customers and their spending score

# %%
df2=df.groupBy("CustomerID") \
      .agg({"UnitPrice":"sum"}).select("CustomerID",col("sum(UnitPrice)")).alias("total_quantity")

# %%
df2.show()
# Out:
# [Stage 31:=============================>                            (1 + 1) / 2]
# +----------+------------------+
# |CustomerID|    sum(UnitPrice)|
# +----------+------------------+
# |     16250|             74.12|
# |     15574| 422.7499999999997|
# |     15555|1563.8299999999963|
# |     15271| 754.0599999999993|
# |     17714|              20.5|
# |     17686|1103.6399999999994|
# |     13865|            117.07|
# |     14157|            108.43|
# |     13610| 667.0999999999995|
# |     13772| 436.1099999999999|
# |     13282|            186.07|
# |     12394|             91.01|
# |     16320|138.91000000000003|
# |     13192|            165.61|
# |     17757|2041.7800000000038|
# |     17551|            109.27|
# |     13187|            139.32|
# |     16549|1997.6900000000055|
# |     12637|1060.1899999999978|
# |     15052|105.33999999999999|
# +----------+------------------+
# only showing top 20 rows

# %%
df.groupBy("CustomerID") \
  .agg(sum("UnitPrice").alias("Total")) \
  .sort(col("Total").desc()) \
  .show()
# Out:
# +----------+------------------+
# |CustomerID|             Total|
# +----------+------------------+
# |      null|1090984.0100000917|
# |     14096| 41376.33000000013|
# |     15098|40278.899999999994|
# |     14911|31060.660000000524|
# |     12744|25108.890000000007|
# |     16029| 24111.14000000003|
# |     17841|20333.180000000022|
# |     12748|15115.600000000006|
# |     12536|13255.220000000003|
# |     12757| 8035.239999999993|
# |     14606| 7839.019999999957|
# |     15502| 7836.839999999998|
# |     14156| 6544.289999999992|
# |     15311| 6267.749999999959|
# |     14527| 5996.639999999981|
# |     14646| 5400.209999999988|
# |     13089| 5166.450000000005|
# |     18102| 5159.730000000001|
# |     15039|4811.7199999999875|
# |     17448|           4287.63|
# +----------+------------------+
# only showing top 20 rows

# %% [markdown]
# #### The above table shows that an unregistered customer spends the highest on multiple products bought.The second highest spending score is 41376.33000000013 by a customer with ID 14096

# %%
df.groupBy("CustomerID","Country") \
  .agg(sum("UnitPrice").alias("Total")) \
  .sort(col("Total").desc()) \
  .show()
# Out:
# [Stage 37:=============================>                            (1 + 1) / 2]
# +----------+--------------+------------------+
# |CustomerID|       Country|             Total|
# +----------+--------------+------------------+
# |      null|United Kingdom| 1067438.210000093|
# |     14096|United Kingdom| 41376.33000000013|
# |     15098|United Kingdom|40278.899999999994|
# |     14911|          EIRE|31060.660000000524|
# |     12744|     Singapore|25108.890000000007|
# |     16029|United Kingdom| 24111.14000000003|
# |     17841|United Kingdom|20333.180000000022|
# |     12748|United Kingdom|15115.600000000006|
# |     12536|        France|13255.220000000003|
# |      null|     Hong Kong|12241.499999999993|
# |      null|          EIRE|10193.610000000039|
# |     12757|      Portugal| 8035.239999999993|
# |     14606|United Kingdom| 7839.019999999957|
# |     15502|United Kingdom| 7836.839999999998|
# |     14156|          EIRE| 6544.289999999992|
# |     15311|United Kingdom| 6267.749999999959|
# |     14527|United Kingdom| 5996.639999999981|
# |     14646|   Netherlands| 5400.209999999988|
# |     13089|United Kingdom| 5166.450000000005|
# |     18102|United Kingdom| 5159.730000000001|
# +----------+--------------+------------------+
# only showing top 20 rows

# %% [markdown]
# #### The above table shows that an unregistered customer living/visiting in the United Kingdom spends the highest on multiple products bought, followed by customers in Eire and Singapore.

# %%
spark.sql("select count(distinct(Country)) from ecom").show()
# Out:
# +-----------------------+
# |count(DISTINCT Country)|
# +-----------------------+
# |                     38|
# +-----------------------+

# %%
spark.sql("select distinct(Description) from ecom").show()
# Out:
# +--------------------+
# |         Description|
# +--------------------+
# |10 COLOUR SPACEBO...|
# |SET/10 BLUE POLKA...|
# |POTTING SHED SOW ...|
# |PAPERWEIGHT KINGS...|
# |WOVEN BERRIES CUS...|
# |WHITE/PINK MINI C...|
# |SET/3 RED GINGHAM...|
# |MAGNETS PACK OF 4...|
# |WHITE CHRYSANTHEM...|
# |WHITE FRANGIPANI ...|
# |SILVER FABRIC MIRROR|
# |PINK  HONEYCOMB P...|
# |PINK BOUDOIR T-LI...|
# | BLACK CHERRY LIGHTS|
# |GLASS CAKE COVER ...|
# |DECORATION SITTIN...|
# |ANTIQUE MID BLUE ...|
# |IVORY ENCHANTED F...|
# |ANTIQUE SILVER TE...|
# |BLUE FELT HANGING...|
# +--------------------+
# only showing top 20 rows

# %%
spark.sql("select count(distinct(Description)) from ecom").show()
# Out:
# +---------------------------+
# |count(DISTINCT Description)|
# +---------------------------+
# |                       4223|
# +---------------------------+

# %%
from pyspark.sql.types import FloatType
data_df=df.withColumn("UnitPrice", df["UnitPrice"].cast(FloatType()))

# %%
data_df
# Out:
# DataFrame[InvoiceNo: string, StockCode: string, Description: string, Quantity: string, InvoiceDate: string, UnitPrice: float, CustomerID: string, Country: string]

# %%
data_df.groupBy("Description").pivot("Country").sum("UnitPrice").show(truncate=False)
# Out:
# 22/01/21 17:40:34 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# [Stage 61:>                                                         (0 + 2) / 2]
# +-----------------------------------+-------------------+-------+-------+-----------------+-----------------+-------------------+---------------+------------------+--------------+-----------------+------------------+------------------+-------+------------------+------------------+------+------------------+-------+------+-----+-----+-------+---------+-----+------------------+------------------+------+-------------------+----+------------+---------+------------------+-----------------+------------------+----+--------------------+------------------+-------------------+
# |Description                        |Australia          |Austria|Bahrain|Belgium          |Brazil           |Canada             |Channel Islands|Cyprus            |Czech Republic|Denmark          |EIRE              |European Community|Finland|France            |Germany           |Greece|Hong Kong         |Iceland|Israel|Italy|Japan|Lebanon|Lithuania|Malta|Netherlands       |Norway            |Poland|Portugal           |RSA |Saudi Arabia|Singapore|Spain             |Sweden           |Switzerland       |USA |United Arab Emirates|United Kingdom    |Unspecified        |
# +-----------------------------------+-------------------+-------+-------+-----------------+-----------------+-------------------+---------------+------------------+--------------+-----------------+------------------+------------------+-------+------------------+------------------+------+------------------+-------+------+-----+-----+-------+---------+-----+------------------+------------------+------+-------------------+----+------------+---------+------------------+-----------------+------------------+----+--------------------+------------------+-------------------+
# |PINK  HONEYCOMB PAPER FAN          |0.6499999761581421 |null   |null   |null             |null             |null               |null           |2.0999999046325684|null          |null             |0.6499999761581421|null              |null   |0.6499999761581421|1.9499999284744263|null  |null              |null   |null  |null |null |null   |null     |null |null              |0.6499999761581421|null  |null               |null|null        |null     |null              |null             |0.6499999761581421|null|null                |107.46999979019165|null               |
# |SET/3 RED GINGHAM ROSE STORAGE BOX |null               |null   |null   |7.5              |3.390000104904175|null               |null           |null              |null          |null             |52.5              |null              |18.75  |22.5              |33.75             |null  |null              |null   |null  |7.5  |null |null   |null     |null |17.3100004196167  |null              |null  |22.5               |null|null        |null     |7.5               |3.75             |3.75              |null|null                |2216.4700095653534|null               |
# |SILVER FABRIC MIRROR               |null               |null   |null   |null             |null             |null               |null           |null              |null          |null             |null              |null              |null   |null              |null              |null  |null              |null   |null  |null |null |null   |null     |null |null              |null              |null  |0.38999998569488525|null|null        |null     |null              |null             |null              |null|null                |31.74999976158142 |0.38999998569488525|
# |SET/10 BLUE POLKADOT PARTY CANDLES |null               |null   |null   |2.5              |null             |null               |null           |null              |null          |null             |7.5               |null              |1.25   |17.5              |18.75             |null  |null              |null   |null  |null |null |null   |null     |null |4.429999828338623 |null              |null  |2.5                |null|null        |null     |5.0               |2.5              |1.25              |3.75|null                |252.25000023841858|3.75               |
# |WHITE CHRYSANTHEMUMS ART FLOWER    |null               |null   |null   |null             |null             |null               |null           |null              |null          |null             |4.199999809265137 |null              |null   |null              |null              |null  |null              |null   |null  |null |null |null   |null     |null |null              |null              |null  |null               |null|null        |null     |null              |null             |null              |null|null                |14.699999332427979|null               |
# |MAGNETS PACK OF 4 VINTAGE LABELS   |0.38999998569488525|null   |null   |null             |null             |0.38999998569488525|null           |null              |null          |null             |null              |null              |null   |4.059999942779541 |3.229999929666519 |null  |null              |null   |null  |null |null |null   |null     |null |null              |null              |null  |0.38999998569488525|null|null        |null     |null              |null             |0.7799999713897705|null|null                |105.50999972224236|null               |
# |10 COLOUR SPACEBOY PEN             |0.8500000238418579 |null   |null   |null             |null             |0.8500000238418579 |null           |null              |null          |null             |4.2500001192092896|null              |null   |10.200000286102295|9.350000262260437 |null  |1.7000000476837158|null   |null  |null |null |null   |null     |null |3.6000001430511475|0.8500000238418579|null  |0.8500000238418579 |null|null        |null     |1.7000000476837158|null             |2.5500000715255737|null|0.8500000238418579  |306.05000472068787|null               |
# |PINK BOUDOIR T-LIGHT HOLDER        |null               |null   |null   |null             |null             |null               |null           |null              |null          |null             |null              |null              |null   |null              |null              |null  |null              |null   |null  |null |null |null   |null     |null |null              |null              |null  |null               |null|null        |null     |null              |null             |null              |null|null                |0.8500000238418579|null               |
# |ANTIQUE MID BLUE FLOWER EARRINGS   |null               |null   |null   |4.25             |null             |null               |null           |null              |null          |null             |null              |null              |null   |null              |null              |null  |null              |null   |null  |null |null |null   |null     |null |null              |null              |null  |null               |null|null        |null     |null              |null             |null              |null|null                |8.400000095367432 |null               |
# |WOVEN BERRIES CUSHION COVER        |null               |null   |null   |null             |null             |null               |null           |null              |null          |null             |null              |null              |null   |null              |null              |null  |null              |null   |null  |null |null |null   |null     |null |null              |null              |null  |null               |null|null        |null     |null              |null             |null              |null|null                |374.7700071334839 |null               |
# |PAPERWEIGHT KINGS CHOICE           |null               |null   |null   |null             |null             |null               |null           |null              |null          |null             |null              |null              |null   |0.8500000238418579|null              |null  |null              |null   |null  |null |null |null   |null     |null |null              |null              |null  |2.549999952316284  |null|null        |null     |null              |null             |null              |null|null                |59.889999747276306|null               |
# |POTTING SHED SOW 'N' GROW SET      |null               |null   |null   |null             |null             |null               |null           |null              |null          |null             |null              |null              |null   |null              |null              |null  |null              |null   |null  |null |null |null   |null     |null |null              |null              |null  |null               |null|null        |null     |null              |null             |null              |null|null                |12.720000267028809|null               |
# |BLACK CHERRY LIGHTS                |null               |null   |null   |null             |null             |null               |null           |null              |null          |null             |null              |null              |null   |null              |null              |null  |null              |null   |null  |null |null |null   |null     |null |null              |null              |null  |null               |null|null        |null     |null              |null             |null              |null|null                |20.25             |null               |
# |WHITE FRANGIPANI NECKLACE          |null               |null   |null   |null             |null             |null               |null           |null              |null          |null             |7.6499998569488525|null              |null   |null              |null              |null  |null              |null   |null  |null |null |null   |null     |null |null              |null              |null  |null               |null|null        |null     |null              |null             |null              |null|null                |37.579999923706055|null               |
# |GLASS CAKE COVER AND PLATE         |null               |null   |null   |null             |null             |null               |null           |null              |null          |null             |null              |null              |null   |null              |null              |null  |null              |null   |null  |null |null |null   |null     |null |null              |null              |null  |null               |null|null        |null     |null              |null             |null              |null|null                |29.899999618530273|null               |
# |DECORATION SITTING BUNNY           |null               |null   |null   |null             |null             |null               |null           |null              |null          |null             |0.5699999928474426|null              |null   |null              |null              |null  |null              |null   |null  |null |null |null   |null     |null |null              |null              |null  |null               |null|null        |null     |null              |null             |null              |null|null                |35.489999771118164|null               |
# |SNACK TRAY I LOVE LONDON           |null               |null   |null   |null             |null             |null               |null           |1.9500000476837158|null          |null             |null              |null              |null   |1.9500000476837158|3.9000000953674316|null  |null              |null   |null  |null |null |null   |null     |null |null              |null              |null  |null               |null|null        |null     |null              |null             |null              |null|null                |88.03000223636627 |null               |
# |VINTAGE LEAF CHOPPING BOARD        |4.150000095367432  |null   |null   |4.949999809265137|null             |null               |null           |4.949999809265137 |null          |4.949999809265137|4.949999809265137 |null              |null   |4.949999809265137 |14.84999942779541 |null  |null              |null   |null  |null |null |null   |null     |null |null              |null              |null  |null               |null|null        |null     |null              |4.949999809265137|4.949999809265137 |null|null                |201.55999374389648|null               |
# |DECROTIVEVINTAGE COFFEE GRINDER BOX|null               |null   |null   |null             |null             |null               |null           |null              |null          |null             |4.949999809265137 |null              |null   |null              |null              |null  |null              |null   |null  |null |null |null   |null     |null |null              |null              |null  |null               |null|null        |null     |null              |null             |null              |null|null                |36.429999351501465|null               |
# |WHITE/PINK MINI CRYSTALS NECKLACE  |null               |null   |null   |null             |null             |null               |null           |null              |null          |null             |null              |null              |null   |null              |null              |null  |null              |null   |null  |null |null |null   |null     |null |null              |null              |null  |null               |null|null        |null     |null              |null             |null              |null|null                |37.570000648498535|null               |
# +-----------------------------------+-------------------+-------+-------+-----------------+-----------------+-------------------+---------------+------------------+--------------+-----------------+------------------+------------------+-------+------------------+------------------+------+------------------+-------+------+-----+-----+-------+---------+-----+------------------+------------------+------+-------------------+----+------------+---------+------------------+-----------------+------------------+----+--------------------+------------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# ### Product details based on country

# %%
country=input()
# Out:
# United Kingdom

# %%
spark.sql("select * from ecom where Country='{}'".format(country)).groupBy("Description").pivot("Country").agg(sum("Quantity")).show(truncate=False)
# Out:
# [Stage 109:>                                                        (0 + 2) / 2]
# +-----------------------------------+--------------+
# |Description                        |United Kingdom|
# +-----------------------------------+--------------+
# |SILVER FABRIC MIRROR               |441.0         |
# |WHITE CHRYSANTHEMUMS ART FLOWER    |53.0          |
# |PINK BOUDOIR T-LIGHT HOLDER        |12.0          |
# |ANTIQUE MID BLUE FLOWER EARRINGS   |3.0           |
# |WOVEN BERRIES CUSHION COVER        |162.0         |
# |SET/3 RED GINGHAM ROSE STORAGE BOX |2618.0        |
# |POTTING SHED SOW 'N' GROW SET      |2.0           |
# |SET/10 BLUE POLKADOT PARTY CANDLES |1878.0        |
# |BLACK CHERRY LIGHTS                |0.0           |
# |GLASS CAKE COVER AND PLATE         |0.0           |
# |MAGNETS PACK OF 4 VINTAGE LABELS   |1045.0        |
# |10 COLOUR SPACEBOY PEN             |4328.0        |
# |WHITE FRANGIPANI NECKLACE          |27.0          |
# |PAPERWEIGHT KINGS CHOICE           |144.0         |
# |WHITE/PINK MINI CRYSTALS NECKLACE  |10.0          |
# |PINK  HONEYCOMB PAPER FAN          |345.0         |
# |DECORATION SITTING BUNNY           |1249.0        |
# |SNACK TRAY I LOVE LONDON           |146.0         |
# |VINTAGE LEAF CHOPPING BOARD        |68.0          |
# |DECROTIVEVINTAGE COFFEE GRINDER BOX|9.0           |
# +-----------------------------------+--------------+
# only showing top 20 rows

# %% [markdown]
# #### The above table shows the description of products corresponding to the quantity sold in Japan

# %%
spark.sql("select * from ecom where Country='{}'".format(country)).groupBy("Description").agg(sum("Quantity")).sort(col("sum(Quantity)").desc()).show(truncate=False)
# Out:
# +-----------------------------------+-------------+
# |Description                        |sum(Quantity)|
# +-----------------------------------+-------------+
# |WORLD WAR 2 GLIDERS ASSTD DESIGNS  |48326.0      |
# |JUMBO BAG RED RETROSPOT            |43167.0      |
# |POPCORN HOLDER                     |34365.0      |
# |ASSORTED COLOUR BIRD ORNAMENT      |33679.0      |
# |WHITE HANGING HEART T-LIGHT HOLDER |33193.0      |
# |PACK OF 12 LONDON TISSUES          |25307.0      |
# |PACK OF 72 RETROSPOT CAKE CASES    |24702.0      |
# |VICTORIAN GLASS HANGING T-LIGHT    |23242.0      |
# |BROCADE RING PURSE                 |22801.0      |
# |ASSORTED COLOURS SILK FAN          |20322.0      |
# |PACK OF 60 PINK PAISLEY CAKE CASES |20288.0      |
# |JUMBO BAG PINK POLKADOT            |18936.0      |
# |SMALL POPCORN HOLDER               |18563.0      |
# |PAPER CHAIN KIT 50'S CHRISTMAS     |18197.0      |
# |RED  HARMONICA IN BOX              |17754.0      |
# |HEART OF WICKER SMALL              |17394.0      |
# |PARTY BUNTING                      |16709.0      |
# |JUMBO BAG STRAWBERRY               |16056.0      |
# |CHARLOTTE BAG SUKI DESIGN          |15974.0      |
# |COLOUR GLASS T-LIGHT HOLDER HANGING|15400.0      |
# +-----------------------------------+-------------+
# only showing top 20 rows

# %% [markdown]
# #### The above table shows the description of products corresponding to the quantity sold in Japan from highest to lowest.

# %%
spark.sql("select * from ecom where Country='{}'".format(country)).groupBy("Description").agg(sum("Quantity")).sort(col("sum(Quantity)").asc()).show(truncate=False)
# Out:
# +----------------------------+-------------+
# |Description                 |sum(Quantity)|
# +----------------------------+-------------+
# |printing smudges/thrown away|-19200.0     |
# |Unsaleable, destroyed.      |-15644.0     |
# |null                        |-13609.0     |
# |check                       |-12030.0     |
# |Printing smudges/thrown away|-9058.0      |
# |Damaged                     |-7540.0      |
# |throw away                  |-5368.0      |
# |damages                     |-4338.0      |
# |incorrect stock entry.      |-4320.0      |
# |thrown away                 |-4110.0      |
# |wrongly marked. 23343 in box|-3100.0      |
# |damages wax                 |-2844.0      |
# |mouldy, thrown away.        |-2600.0      |
# |thrown away-can't sell      |-2472.0      |
# |sold as set on dotcom       |-2393.0      |
# |Thrown away-rusty           |-2376.0      |
# |?missing                    |-2331.0      |
# |??                          |-1849.0      |
# |mouldy, unsaleable.         |-1681.0      |
# |damaged                     |-1632.0      |
# +----------------------------+-------------+
# only showing top 20 rows

# %% [markdown]
# #### The above table shows the description of products corresponding to the quantity sold in Japan from lowest to highest.

# %%
spark.sql("select * from ecom where Country='{}'".format(country)).groupBy("Description").pivot("Country").agg(sum("UnitPrice")).show(truncate=False)
# Out:
# +-----------------------------------+------------------+
# |Description                        |United Kingdom    |
# +-----------------------------------+------------------+
# |SILVER FABRIC MIRROR               |31.75             |
# |WHITE CHRYSANTHEMUMS ART FLOWER    |14.7              |
# |PINK BOUDOIR T-LIGHT HOLDER        |0.85              |
# |ANTIQUE MID BLUE FLOWER EARRINGS   |8.4               |
# |WOVEN BERRIES CUSHION COVER        |374.76999999999975|
# |SET/3 RED GINGHAM ROSE STORAGE BOX |2216.4700000000034|
# |POTTING SHED SOW 'N' GROW SET      |12.72             |
# |SET/10 BLUE POLKADOT PARTY CANDLES |252.25            |
# |BLACK CHERRY LIGHTS                |20.25             |
# |GLASS CAKE COVER AND PLATE         |29.9              |
# |MAGNETS PACK OF 4 VINTAGE LABELS   |105.50999999999999|
# |10 COLOUR SPACEBOY PEN             |306.0499999999993 |
# |WHITE FRANGIPANI NECKLACE          |37.580000000000005|
# |PAPERWEIGHT KINGS CHOICE           |59.89             |
# |WHITE/PINK MINI CRYSTALS NECKLACE  |37.57000000000001 |
# |PINK  HONEYCOMB PAPER FAN          |107.47000000000006|
# |DECORATION SITTING BUNNY           |35.49000000000001 |
# |SNACK TRAY I LOVE LONDON           |88.03000000000002 |
# |VINTAGE LEAF CHOPPING BOARD        |201.55999999999992|
# |DECROTIVEVINTAGE COFFEE GRINDER BOX|36.43             |
# +-----------------------------------+------------------+
# only showing top 20 rows

# %%
spark.sql("select * from ecom where Country='{}'".format(country)).groupBy("Description").agg(sum("UnitPrice")).sort(col("sum(UnitPrice)").asc()).show(truncate=False)
# Out:
# +-------------------------------+--------------+
# |Description                    |sum(UnitPrice)|
# +-------------------------------+--------------+
# |Adjust bad debt                |-11062.06     |
# |sold in set?                   |0.0           |
# |Adjustment                     |0.0           |
# |Damages/samples                |0.0           |
# |damages/credits from ASOS.     |0.0           |
# |Thrown away-rusty              |0.0           |
# |sold as set/6 by dotcom        |0.0           |
# |amazon                         |0.0           |
# |thrown away-can't sell         |0.0           |
# |samples/damages                |0.0           |
# |?sold as sets?                 |0.0           |
# |damages/display                |0.0           |
# |?lost                          |0.0           |
# |Damaged                        |0.0           |
# |Printing smudges/thrown away   |0.0           |
# |printing smudges/thrown away   |0.0           |
# |POSSIBLE DAMAGES OR LOST?      |0.0           |
# |incorrectly put back into stock|0.0           |
# |amazon sales                   |0.0           |
# |wrong barcode                  |0.0           |
# +-------------------------------+--------------+
# only showing top 20 rows

# %% [markdown]
# #### The product with the lowest price in Japan is a pack of 12 circus parade tissues.

# %%
spark.sql("select * from ecom where Country='{}'".format(country)).groupBy("Description").agg(sum("UnitPrice")).sort(col("sum(UnitPrice)").desc()).show(truncate=False)
# Out:
# [Stage 148:============================>                            (1 + 1) / 2]
# +----------------------------------+------------------+
# |Description                       |sum(UnitPrice)    |
# +----------------------------------+------------------+
# |AMAZON FEE                        |249042.67999999996|
# |DOTCOM POSTAGE                    |206252.06000000006|
# |Manual                            |129871.21         |
# |REGENCY CAKESTAND 3 TIER          |26182.209999999992|
# |POSTAGE                           |19055.80000000001 |
# |PARTY BUNTING                     |9532.069999999869 |
# |CRUK Commission                   |7933.43           |
# |SET OF 3 CAKE TINS PANTRY DESIGN  |7752.729999999922 |
# |CREAM SWEETHEART MINI CHEST       |7521.16           |
# |Bank Charges                      |7505.641          |
# |WHITE HANGING HEART T-LIGHT HOLDER|7309.769999999918 |
# |ENAMEL BREAD BIN CREAM            |7232.380000000001 |
# |SET/4 WHITE RETRO STORAGE CUBES   |6971.049999999994 |
# |VINTAGE RED KITCHEN CABINET       |6555.5            |
# |PICNIC BASKET WICKER LARGE        |6426.9599999999755|
# |DOORMAT KEEP CALM AND COME IN     |6244.359999999993 |
# |RED RETROSPOT CAKE STAND          |6221.439999999978 |
# |IVORY KITCHEN SCALES              |6018.110000000008 |
# |SPOTTY BUNTING                    |5947.589999999969 |
# |DOORMAT RED RETROSPOT             |5734.989999999983 |
# +----------------------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# #### The product with the highest price in Japan is a manual.

# %% [markdown]
# ### Importing libraries for data visualization

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
from pyspark.sql.types import IntegerType
data1_df=df.withColumn("Quantity", df["Quantity"].cast(IntegerType()))

# %%
dfPlot= data1_df.groupBy("Country").sum("Quantity")
x=dfPlot.toPandas()["Country"].values.tolist()
y=dfPlot.toPandas()["sum(Quantity)"].values.tolist()
fig=plt.figure(figsize=(16,8))
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### The above graph shows that the United Kingdom has sold the maximum number of products in the year 2010 and 2011

# %%
datax=df.toPandas()

# %%
datax
# Out:
#        InvoiceNo StockCode                          Description Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER        6
# 1         536365     71053                  WHITE METAL LANTERN        6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER        8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE        6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.        6
# ...          ...       ...                                  ...      ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS       12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE        4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT         3
#
#             InvoiceDate UnitPrice CustomerID         Country
# 0        12/1/2010 8:26      2.55      17850  United Kingdom
# 1        12/1/2010 8:26      3.39      17850  United Kingdom
# 2        12/1/2010 8:26      2.75      17850  United Kingdom
# 3        12/1/2010 8:26      3.39      17850  United Kingdom
# 4        12/1/2010 8:26      3.39      17850  United Kingdom
# ...                 ...       ...        ...             ...
# 541904  12/9/2011 12:50      0.85      12680          France
# 541905  12/9/2011 12:50       2.1      12680          France
# 541906  12/9/2011 12:50      4.15      12680          France
# 541907  12/9/2011 12:50      4.15      12680          France
# 541908  12/9/2011 12:50      4.95      12680          France
#
# [541909 rows x 8 columns]

# %%
datax["Quantity"]=datax["Quantity"].astype(int)

# %%
datax
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate UnitPrice CustomerID         Country
# 0        12/1/2010 8:26      2.55      17850  United Kingdom
# 1        12/1/2010 8:26      3.39      17850  United Kingdom
# 2        12/1/2010 8:26      2.75      17850  United Kingdom
# 3        12/1/2010 8:26      3.39      17850  United Kingdom
# 4        12/1/2010 8:26      3.39      17850  United Kingdom
# ...                 ...       ...        ...             ...
# 541904  12/9/2011 12:50      0.85      12680          France
# 541905  12/9/2011 12:50       2.1      12680          France
# 541906  12/9/2011 12:50      4.15      12680          France
# 541907  12/9/2011 12:50      4.15      12680          France
# 541908  12/9/2011 12:50      4.95      12680          France
#
# [541909 rows x 8 columns]

# %%
datax.dtypes
# Out:
# InvoiceNo      object
# StockCode      object
# Description    object
# Quantity        int64
# InvoiceDate    object
# UnitPrice      object
# CustomerID     object
# Country        object
# dtype: object

# %%
import seaborn as sns
plt.figure(figsize=(16, 6))
plt.xticks(rotation=90)
sns.barplot(datax['Country'], datax['Quantity'])
# Out:
# /home/niharika/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Country', ylabel='Quantity'>

# %% [markdown]
# #### The above graph shows that Netherlands has sold a particular product to a single customer in high number, followed by Sweden and Japan

# %%
datax["UnitPrice"]=datax["UnitPrice"].astype(float)

# %%
plt.figure(figsize=(16, 6))
plt.xticks(rotation=90)
sns.barplot(datax['Country'], datax['UnitPrice'])
# Out:
# /home/niharika/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Country', ylabel='UnitPrice'>

# %% [markdown]
# #### The above graph shows that the customers in Singapore have the highest spending score.

# %%
plt.figure(figsize=(16, 6))
plt.xticks(rotation=90)
sns.countplot(datax['Country'])
# Out:
# /home/niharika/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %% [markdown]
# #### The above graph shows that the highest purshase score is from the customers staying in the United Kingdom

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import datetime, nltk, warnings
import matplotlib.cm as cm
import itertools
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode,iplot
init_notebook_mode(connected=True)
warnings.filterwarnings("ignore")
plt.rcParams["patch.force_edgecolor"] = True
plt.style.use('fivethirtyeight')
mpl.rc('patch', edgecolor = 'dimgray', linewidth=1)
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
temp = datax[['CustomerID', 'InvoiceNo', 'Country']].groupby(['CustomerID', 'InvoiceNo', 'Country']).count()
temp = temp.reset_index(drop = False)
countries = temp['Country'].value_counts()
print('No of countries: {}'.format(len(countries)))
# Out:
# No of countries: 37

# %%
dat = dict(type='choropleth',
locations = countries.index,
locationmode = 'country names', z = countries,
text = countries.index, colorbar = {'title':'Order no.'},
colorscale=[[0, 'rgb(224,255,255)'],
            [0.01, 'rgb(166,206,227)'], [0.02, 'rgb(31,120,180)'],
            [0.03, 'rgb(178,223,138)'], [0.05, 'rgb(51,160,44)'],
            [0.10, 'rgb(251,154,153)'], [0.20, 'rgb(255,255,0)'],
            [1, 'rgb(227,26,28)']],    
reversescale = False)
#_______________________
layout = dict(title='Number of orders per country',
geo = dict(showframe = True, projection={'type':'mercator'}))
#______________
choromap = go.Figure(data = [dat], layout = layout)
iplot(choromap, validate=False)
# Out:
# <div>                            <div id="01cc01a1-1057-49dc-97ba-10e6b99ff0fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01cc01a1-1057-49dc-97ba-10e6b99ff0fb")) {                    Plotly.newPlot(                        "01cc01a1-1057-49dc-97ba-10e6b99ff0fb",                        [{"colorbar":{"title":{"text":"Order no."}},"colorscale":[[0,"rgb(224,255,255)"],[0.01,"rgb(166,206,227)"],[0.02,"rgb(31,120,180)"],[0.03,"rgb(178,223,138)"],[0.05,"rgb(51,160,44)"],[0.1,"rgb(251,154,153)"],[0.2,"rgb(255,255,0)"],[1,"rgb(227,26,28)"]],"locationmode":"country names","locations":["United Kingdom","Germany","France","EIRE","Belgium","Spain","Netherlands","Switzerland","Portugal","Australia","Italy","Finland","Sweden","Norway","Channel Islands","Japan","Poland","Denmark","Cyprus","Austria","Singapore","Malta","Unspecified","USA","Iceland","Israel","Canada","Greece","Czech Republic","European Community","Lithuania","United Arab Emirates","Saudi Arabia","Bahrain","RSA","Lebanon","Brazil"],"reversescale":false,"text":["United Kingdom","Germany","France","EIRE","Belgium","Spain","Netherlands","Switzerland","Portugal","Australia","Italy","Finland","Sweden","Norway","Channel Islands","Japan","Poland","Denmark","Cyprus","Austria","Singapore","Malta","Unspecified","USA","Iceland","Israel","Canada","Greece","Czech Republic","European Community","Lithuania","United Arab Emirates","Saudi Arabia","Bahrain","RSA","Lebanon","Brazil"],"z":[19857,603,458,319,119,105,101,71,70,69,55,48,46,40,33,28,24,21,20,19,10,10,8,7,7,6,6,6,5,5,4,3,2,2,1,1,1],"type":"choropleth"}],                        {"geo":{"projection":{"type":"mercator"},"showframe":true},"title":{"text":"Number of orders per country"},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"tic ...

# %%
d_parser = lambda x: pd.datetime.strptime(x, '%m/%d/%Y %H:%M')
datax = pd.read_csv('/home/niharika/data.csv', encoding= 'unicode_escape',parse_dates=['InvoiceDate'], date_parser=d_parser)
# Out:
# /tmp/ipykernel_27823/1702493330.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   d_parser = lambda x: pd.datetime.strptime(x, '%m/%d/%Y %H:%M')

# %%
datax.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
datax.loc[0, 'InvoiceDate'].day_name()
# Out:
# 'Wednesday'

# %%
datax['InvoiceDate'].dt.day_name()
# Out:
# 0         Wednesday
# 1         Wednesday
# 2         Wednesday
# 3         Wednesday
# 4         Wednesday
#             ...
# 541904       Friday
# 541905       Friday
# 541906       Friday
# 541907       Friday
# 541908       Friday
# Name: InvoiceDate, Length: 541909, dtype: object

# %%
datax['DayOfWeek'] = datax['InvoiceDate'].dt.day_name()

# %%
datax
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  DayOfWeek
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom  Wednesday
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  Wednesday
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom  Wednesday
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  Wednesday
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  Wednesday
# ...                    ...        ...         ...             ...        ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France     Friday
# 541905 2011-12-09 12:50:00       2.10     12680.0          France     Friday
# 541906 2011-12-09 12:50:00       4.15     12680.0          France     Friday
# 541907 2011-12-09 12:50:00       4.15     12680.0          France     Friday
# 541908 2011-12-09 12:50:00       4.95     12680.0          France     Friday
#
# [541909 rows x 9 columns]

# %%
datax['InvoiceDate'].min()
# Out:
# Timestamp('2010-12-01 08:26:00')

# %%
datax['InvoiceDate'].max()
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
datax['InvoiceDate'].max() - datax['InvoiceDate'].min()
# Out:
# Timedelta('373 days 04:24:00')

# %%
filt = (datax['InvoiceDate'] >= pd.to_datetime('2010-12-21')) & (datax['InvoiceDate'] < pd.to_datetime('2011-11-01'))
datax.loc[filt]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 39641     539658    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 39642     539658     84949        SILVER HANGING T-LIGHT HOLDER         6
# 39643     539658     21756             BATH BUILDING BLOCK WORD         3
# 39644     539658     22977         DOLLY GIRL CHILDRENS EGG CUP        12
# 39645     539658    84032B  CHARLIE + LOLA RED HOT WATER BOTTLE         6
# ...          ...       ...                                  ...       ...
# 431668    573695     23407       SET OF 2 TRAYS HOME SWEET HOME         2
# 431669    573695     23543                  WALL ART KEEP CALM          1
# 431670    573695     23397          FOOT STOOL HOME SWEET HOME          4
# 431671    573726     72817                                check       -67
# 431672    573734     72818                                check       -26
#
#                InvoiceDate  UnitPrice  CustomerID         Country DayOfWeek
# 39641  2010-12-21 09:34:00       2.95     17213.0  United Kingdom   Tuesday
# 39642  2010-12-21 09:34:00       1.65     17213.0  United Kingdom   Tuesday
# 39643  2010-12-21 09:34:00       5.95     17213.0  United Kingdom   Tuesday
# 39644  2010-12-21 09:34:00       1.25     17213.0  United Kingdom   Tuesday
# 39645  2010-12-21 09:34:00       2.95     17213.0  United Kingdom   Tuesday
# ...                    ...        ...         ...             ...       ...
# 431668 2011-10-31 17:13:00       9.95     15023.0  United Kingdom    Monday
# 431669 2011-10-31 17:13:00       8.25     15023.0  United Kingdom    Monday
# 431670 2011-10-31 17:13:00       9.95     15023.0  United Kingdom    Monday
# 431671 2011-10-31 17:18:00       0.00         NaN  United Kingdom    Monday
# 431672 2011-10-31 17:19:00       0.00         NaN  United Kingdom    Monday
#
# [392032 rows x 9 columns]

# %%
datax.set_index('InvoiceDate', inplace=True)

# %%
datax
# Out:
#                     InvoiceNo StockCode                          Description  \
# InvoiceDate
# 2010-12-01 08:26:00    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 2010-12-01 08:26:00    536365     71053                  WHITE METAL LANTERN
# 2010-12-01 08:26:00    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 2010-12-01 08:26:00    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 2010-12-01 08:26:00    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...                       ...       ...                                  ...
# 2011-12-09 12:50:00    581587     22613          PACK OF 20 SPACEBOY NAPKINS
# 2011-12-09 12:50:00    581587     22899         CHILDREN'S APRON DOLLY GIRL
# 2011-12-09 12:50:00    581587     23254        CHILDRENS CUTLERY DOLLY GIRL
# 2011-12-09 12:50:00    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 2011-12-09 12:50:00    581587     22138        BAKING SET 9 PIECE RETROSPOT
#
#                      Quantity  UnitPrice  CustomerID         Country  \
# InvoiceDate
# 2010-12-01 08:26:00         6       2.55     17850.0  United Kingdom
# 2010-12-01 08:26:00         6       3.39     17850.0  United Kingdom
# 2010-12-01 08:26:00         8       2.75     17850.0  United Kingdom
# 2010-12-01 08:26:00         6       3.39     17850.0  United Kingdom
# 2010-12-01 08:26:00         6       3.39     17850.0  United Kingdom
# ...                       ...        ...         ...             ...
# 2011-12-09 12:50:00        12       0.85     12680.0          France
# 2011-12-09 12:50:00         6       2.10     12680.0          France
# 2011-12-09 12:50:00         4       4.15     12680.0          France
# 2011-12-09 12:50:00         4       4.15     12680.0          France
# 2011-12-09 12:50:00         3       4.95     12680.0          France
#
#                      DayOfWeek
# InvoiceDate
# 2010-12-01 08:26:00  Wednesday
# 2010-12-01 08:26:00  Wednesday
# 2010-12-01 08:26:00  Wednesday
# 2010-12-01 08:26:00  Wednesday
# 2010-12-01 08:26:00  Wednesday
# ...                        ...
# 2011-12-09 12:50:00     Friday
# 2011-12-09 12:50:00     Friday
# 2011-12-09 12:50:00     Friday
# 2011-12-09 12:50:00     Friday
# 2011-12-09 12:50:00     Friday
#
# [541909 rows x 8 columns]

# %%
datax['2010-01':'2011-02']['UnitPrice'].mean()
# Out:
# 5.323229885603297

# %%
datax['2010-01':'2011-02']['UnitPrice'].max()
# Out:
# 16888.02

# %%
highs = datax['UnitPrice'].resample('D').sum()
highs['2011-12-09']
# Out:
# 9226.48

# %%
# %matplotlib inline

# %%
plt.figure(figsize=(16, 6))
highs.plot()
# Out:
# <AxesSubplot:xlabel='InvoiceDate'>

# %%
datax['total_price'] = datax['Quantity'] * datax['UnitPrice']

# %%
datax
# Out:
#                     InvoiceNo StockCode                          Description  \
# InvoiceDate
# 2010-12-01 08:26:00    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 2010-12-01 08:26:00    536365     71053                  WHITE METAL LANTERN
# 2010-12-01 08:26:00    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 2010-12-01 08:26:00    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 2010-12-01 08:26:00    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...                       ...       ...                                  ...
# 2011-12-09 12:50:00    581587     22613          PACK OF 20 SPACEBOY NAPKINS
# 2011-12-09 12:50:00    581587     22899         CHILDREN'S APRON DOLLY GIRL
# 2011-12-09 12:50:00    581587     23254        CHILDRENS CUTLERY DOLLY GIRL
# 2011-12-09 12:50:00    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 2011-12-09 12:50:00    581587     22138        BAKING SET 9 PIECE RETROSPOT
#
#                      Quantity  UnitPrice  CustomerID         Country  \
# InvoiceDate
# 2010-12-01 08:26:00         6       2.55     17850.0  United Kingdom
# 2010-12-01 08:26:00         6       3.39     17850.0  United Kingdom
# 2010-12-01 08:26:00         8       2.75     17850.0  United Kingdom
# 2010-12-01 08:26:00         6       3.39     17850.0  United Kingdom
# 2010-12-01 08:26:00         6       3.39     17850.0  United Kingdom
# ...                       ...        ...         ...             ...
# 2011-12-09 12:50:00        12       0.85     12680.0          France
# 2011-12-09 12:50:00         6       2.10     12680.0          France
# 2011-12-09 12:50:00         4       4.15     12680.0          France
# 2011-12-09 12:50:00         4       4.15     12680.0          France
# 2011-12-09 12:50:00         3       4.95     12680.0          France
#
#                      DayOfWeek  total_price
# InvoiceDate
# 2010-12-01 08:26:00  Wednesday        15.30
# 2010-12-01 08:26:00  Wednesday        20.34
# 2010-12-01 08:26:00  Wednesday        22.00
# 2010-12-01 08:26:00  Wednesday        20.34
# 2010-12-01 08:26:00  Wednesday        20.34
# ...                        ...          ...
# 2011-12-09 12:50:00     Friday        10.20
# 2011-12-09 12:50:00     Friday        12.60
# 2011-12-09 12:50:00     Friday        16.60
# 2011-12-09 12:50:00     Friday        16.60
# 2011-12-09 12:50:00     Friday        14.85
#
# [541909 rows x 9 columns]

# %%
country1=input()
# Out:
# Japan

# %%
country2=input()
# Out:
# France

# %%
datax1 = datax[datax.Country == country1]

# %%
datax2 = datax[datax.Country == country2]

# %%
prices_df1 = pd.DataFrame(datax1.groupby("InvoiceDate").total_price.sum())
prices_df1 = prices_df1.iloc[:-1]
prices_df1
# Out:
#                      total_price
# InvoiceDate
# 2010-12-05 15:46:00       320.08
# 2010-12-09 10:44:00      3794.40
# 2010-12-12 11:44:00      3590.59
# 2011-01-06 18:06:00      -109.80
# 2011-02-04 10:31:00        21.64
# 2011-02-04 10:32:00        23.93
# 2011-02-09 11:21:00      5735.24
# 2011-03-02 16:33:00       -43.39
# 2011-03-02 16:35:00        15.30
# 2011-03-04 12:42:00        17.55
# 2011-03-07 11:46:00       -45.57
# 2011-03-07 13:38:00        16.05
# 2011-03-07 16:40:00       -16.05
# 2011-03-07 16:41:00       -17.55
# 2011-04-04 10:12:00     -1591.20
# 2011-04-05 13:56:00      3599.38
# 2011-04-18 09:00:00      2949.12
# 2011-04-26 11:06:00       -85.47
# 2011-05-13 09:33:00      1351.45
# 2011-06-22 10:11:00      1607.04
# 2011-07-24 14:12:00       174.00
# 2011-07-27 09:32:00      3680.40
# 2011-08-23 11:36:00       -49.79
# 2011-09-14 09:31:00       112.08
# 2011-10-26 09:54:00       229.64
# 2011-10-26 13:21:00      1718.40
# 2011-11-17 10:52:00      4808.48
# 2011-11-29 15:52:00      3651.60

# %%
prices_df2 = pd.DataFrame(datax2.groupby("InvoiceDate").total_price.sum())
prices_df2 = prices_df2.iloc[:-1]
prices_df2
# Out:
#                      total_price
# InvoiceDate
# 2010-12-01 08:45:00       855.86
# 2010-12-03 09:51:00        89.14
# 2010-12-03 13:59:00       336.24
# 2010-12-05 11:57:00      1526.92
# 2010-12-07 10:08:00      1033.52
# ...                          ...
# 2011-12-06 16:34:00       314.44
# 2011-12-07 08:07:00       694.77
# 2011-12-07 15:02:00       422.85
# 2011-12-08 11:35:00       165.90
# 2011-12-08 11:46:00       -19.20
#
# [460 rows x 1 columns]

# %%
weekly_prices1 = prices_df1.resample("W").sum()
weekly_prices1.head()
# Out:
#              total_price
# InvoiceDate
# 2010-12-05        320.08
# 2010-12-12       7384.99
# 2010-12-19          0.00
# 2010-12-26          0.00
# 2011-01-02          0.00

# %%
weekly_prices2 = prices_df2.resample("W").sum()
weekly_prices2.head()
# Out:
#              total_price
# InvoiceDate
# 2010-12-05       2808.16
# 2010-12-12       4527.01
# 2010-12-19        537.32
# 2010-12-26       1702.87
# 2011-01-02          0.00

# %%
fig, ax = plt.subplots(figsize = (12, 5), facecolor = "#e5e5e5")
ax.set_facecolor("#101820")

weekly_prices1.plot(ax = ax).set_title("Weekly Revenue")
ax.legend(facecolor = "#101820", labelcolor = "#e5e5e5")

weekly_prices2.plot(ax = ax).set_title("Weekly Revenue")
ax.legend(facecolor = "#101830", labelcolor = "#e5e5f6")

sns.despine()
plt.show()

# %%
country3= input()
# Out:
# United Kingdom

# %%
datax3 = datax[datax.Country == country3]

# %%
prices_df3 = pd.DataFrame(datax3.groupby("InvoiceDate").total_price.sum())
prices_df3 = prices_df3.iloc[:-1]
prices_df3
# Out:
#                      total_price
# InvoiceDate
# 2010-12-01 08:26:00       139.12
# 2010-12-01 08:28:00        22.20
# 2010-12-01 08:34:00       348.78
# 2010-12-01 08:35:00        17.85
# 2010-12-01 09:00:00       204.00
# ...                          ...
# 2011-12-09 12:20:00       145.29
# 2011-12-09 12:21:00        29.88
# 2011-12-09 12:23:00       124.60
# 2011-12-09 12:25:00       140.64
# 2011-12-09 12:31:00       329.05
#
# [21219 rows x 1 columns]

# %%
weekly_prices3 = prices_df3.resample("W").sum()
weekly_prices3.head()
# Out:
#              total_price
# InvoiceDate
# 2010-12-05     166116.72
# 2010-12-12     244020.45
# 2010-12-19     191501.99
# 2010-12-26      75103.46
# 2011-01-02          0.00

# %%
fig, ax = plt.subplots(figsize = (12, 5), facecolor = "#e5e5e5")
ax.set_facecolor("#101820")

weekly_prices3.plot(ax = ax).set_title("Weekly Revenue for United Kingdom")
ax.legend(facecolor = "#101820", labelcolor = "#e5e5e5")

sns.despine()
plt.show()

# %%
daily_sales = pd.DataFrame(datax3.groupby("InvoiceDate").sum().resample("D").sum()["total_price"])
daily_sales
# Out:
#              total_price
# InvoiceDate
# 2010-12-01      54615.15
# 2010-12-02      46053.93
# 2010-12-03      39985.44
# 2010-12-04          0.00
# 2010-12-05      25462.20
# ...                  ...
# 2011-12-05      54715.25
# 2011-12-06      50307.31
# 2011-12-07      55028.58
# 2011-12-08      78437.90
# 2011-12-09      27345.03
#
# [374 rows x 1 columns]

# %%
daily_sales.loc["2010-12-23" : "2011-1-4"]
# Out:
#              total_price
# InvoiceDate
# 2010-12-23      10186.86
# 2010-12-24          0.00
# 2010-12-25          0.00
# 2010-12-26          0.00
# 2010-12-27          0.00
# 2010-12-28          0.00
# 2010-12-29          0.00
# 2010-12-30          0.00
# 2010-12-31          0.00
# 2011-01-01          0.00
# 2011-01-02          0.00
# 2011-01-03          0.00
# 2011-01-04      14442.92

# %%
import numpy as np

# %%
daily_sales.reset_index(inplace = True)
daily_sales["Closed"] = np.where((daily_sales.total_price == 0), 1, 0)
daily_sales.set_index("InvoiceDate", inplace = True)

# %%
daily_sales["weekday"] = daily_sales.index.day_name()
daily_sales
# Out:
#              total_price  Closed    weekday
# InvoiceDate
# 2010-12-01      54615.15       0  Wednesday
# 2010-12-02      46053.93       0   Thursday
# 2010-12-03      39985.44       0     Friday
# 2010-12-04          0.00       1   Saturday
# 2010-12-05      25462.20       0     Sunday
# ...                  ...     ...        ...
# 2011-12-05      54715.25       0     Monday
# 2011-12-06      50307.31       0    Tuesday
# 2011-12-07      55028.58       0  Wednesday
# 2011-12-08      78437.90       0   Thursday
# 2011-12-09      27345.03       0     Friday
#
# [374 rows x 3 columns]

# %%
daily_sales.groupby("weekday").total_price.sum()
# Out:
# weekday
# Friday       1276033.171
# Monday       1364079.051
# Saturday           0.000
# Sunday        707234.501
# Thursday     1720142.310
# Tuesday      1683364.841
# Wednesday    1436952.490
# Name: total_price, dtype: float64

# %%
daily_sales_workdays = daily_sales[daily_sales.total_price > 0].copy()
daily_sales.drop("weekday", axis = 1, inplace = True)
daily_sales_workdays.drop("weekday", axis = 1, inplace = True)

# %%
fig, axes = plt.subplots(2, 1, sharex = True, figsize = (14, 10), facecolor = "#e5e5e5")

for ax in axes: ax.set_facecolor("#101820")
    
sns.lineplot(x = daily_sales.index, y = daily_sales.total_price, 
             ax = axes[0], label = "Daily Sales").set_title("For Daily Sales \nIncludes Vacation Days")

sns.lineplot(x = daily_sales.index, y = daily_sales.total_price.rolling(7).mean(), 
             ax = axes[0], label = "Rolling Mean for 7 Days")
sns.lineplot(x = daily_sales.index, y = daily_sales.total_price.rolling(35).mean(), 
             ax = axes[0], label = "Rolling Mean for 35 Days")
sns.lineplot(x = daily_sales.index, y = daily_sales.total_price.rolling(70).mean(), 
             ax = axes[0], label = "Rolling Mean for 70 Days")
sns.lineplot(x = daily_sales.index, y = daily_sales.total_price.rolling(140).mean(), 
             ax = axes[0], label = "Rolling Mean for 140 Days")
sns.lineplot(x = daily_sales_workdays.index, y = daily_sales_workdays.total_price, 
             ax = axes[1], label = "Daily Sales").set_title("Daily Sales \nJust Work Days")

sns.lineplot(x = daily_sales_workdays.index, y = daily_sales_workdays.total_price.rolling(6).mean(), 
             ax = axes[1], label = "Rolling Mean for 7 Days")
sns.lineplot(x = daily_sales_workdays.index, y = daily_sales_workdays.total_price.rolling(30).mean(),
             ax = axes[1], label = "Rolling Mean for 30 Days")
sns.lineplot(x = daily_sales_workdays.index, y = daily_sales_workdays.total_price.rolling(60).mean(), 
             ax = axes[1], label = "Rolling Mean for 60 Days")
sns.lineplot(x = daily_sales_workdays.index, y = daily_sales_workdays.total_price.rolling(120).mean(), 
             ax = axes[1], label = "Rolling Mean for 120 Days")

for ax in axes: ax.legend(facecolor = "#101820", labelcolor = "#e5e5e5")
    
sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Social Influence on Shopping

# %% [markdown]
# #### Loading the data

# %%
dfx=spark.read.format("csv").option("header","true").option("inferSchema","true").option("mode","failfast").load("/home/niharika/Downloads/social-influence.csv")

# %%
dfx.createOrReplaceTempView("social")

# %% [markdown]
# #### Around 1450 people were asked to answer to the question "What social platform has influence your online shopping the most?"

# %%
spark.sql("select * from social").show()
# Out:
# +--------------------+-----------+------------------+---------+-----+----------+
# |            Question|SegmentType|SegmentDescription|   Answer|Count|Percentage|
# +--------------------+-----------+------------------+---------+-----+----------+
# |What social platf...|     Mobile|    Global results| Facebook|  548|     0.205|
# |What social platf...|     Mobile|    Global results|Instagram|  916|     0.342|
# |What social platf...|     Mobile|    Global results| Snapchat|   86|     0.032|
# |What social platf...|     Mobile|    Global results|  Twitter|  179|     0.067|
# |What social platf...|     Mobile|    Global results|     None|  947|     0.354|
# |What social platf...|        Web|               Web| Facebook|    0|       0.0|
# |What social platf...|        Web|               Web|Instagram|    0|       0.0|
# |What social platf...|        Web|               Web| Snapchat|    0|       0.0|
# |What social platf...|        Web|               Web|  Twitter|    0|       0.0|
# |What social platf...|        Web|               Web|     None|    2|       1.0|
# |What social platf...|     Gender|     Female voters| Facebook|  222|     0.199|
# |What social platf...|     Gender|     Female voters|Instagram|  535|      0.48|
# |What social platf...|     Gender|     Female voters| Snapchat|   29|     0.026|
# |What social platf...|     Gender|     Female voters|  Twitter|   57|     0.051|
# |What social platf...|     Gender|     Female voters|     None|  271|     0.243|
# |What social platf...|     Gender|       Male voters| Facebook|  326|     0.209|
# |What social platf...|     Gender|       Male voters|Instagram|  380|     0.243|
# |What social platf...|     Gender|       Male voters| Snapchat|   56|     0.036|
# |What social platf...|     Gender|       Male voters|  Twitter|  122|     0.078|
# |What social platf...|     Gender|       Male voters|     None|  678|     0.434|
# +--------------------+-----------+------------------+---------+-----+----------+
# only showing top 20 rows

# %%
spark.sql("select distinct(SegmentType) from social").show()
# Out:
# +-----------+
# |SegmentType|
# +-----------+
# |     Custom|
# |     Mobile|
# |     Gender|
# |        Web|
# | University|
# +-----------+

# %%
spark.sql("select distinct(SegmentDescription) from social").show()
# Out:
# +--------------------+
# |  SegmentDescription|
# +--------------------+
# |or private school...|
# | New York University|
# |in Greek life? Ye...|
# |  Cornell University|
# |   Butler University|
# |    you a virgin? No|
# |closely identify ...|
# |University of Guelph|
# |Wilfred Laurier U...|
# | Medford High School|
# |your zodiac sign?...|
# |University of Mis...|
# |University of Sou...|
# |Newcastle University|
# |  Indiana University|
# |    Emory University|
# |      Illinois State|
# |grow up speaking?...|
# |James Madison Uni...|
# |Sexual orientatio...|
# +--------------------+
# only showing top 20 rows

# %%
spark.sql("select count(distinct(SegmentDescription)) from social").show()
# Out:
# +----------------------------------+
# |count(DISTINCT SegmentDescription)|
# +----------------------------------+
# |                               289|
# +----------------------------------+

# %%
spark.sql("select distinct(Answer) from social").show()
# Out:
# +---------+
# |   Answer|
# +---------+
# |     None|
# |Instagram|
# |  Twitter|
# | Snapchat|
# | Facebook|
# +---------+

# %%
spark.sql("select distinct(Question) from social").show()
# Out:
# +--------------------+
# |            Question|
# +--------------------+
# |What social platf...|
# +--------------------+

# %%
spark.sql("select count(*) from social").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |    1450|
# +--------+

# %%
dfx.groupBy("Answer") \
  .agg(sum("Count").alias("Total")) \
  .sort(col("Total").desc()) \
  .show()
# Out:
# +---------+-----+
# |   Answer|Total|
# +---------+-----+
# |     None|18936|
# |Instagram|16524|
# | Facebook|10329|
# |  Twitter| 3407|
# | Snapchat| 1574|
# +---------+-----+

# %% [markdown]
# #### Majority of the people were not influenced by any online platform for shopping, followed by 16524 who were influenced by Instagram.

# %%
dfx.groupBy("SegmentType") \
  .agg(sum("Count").alias("Total")) \
  .sort(col("Total").desc()) \
  .show()
# Out:
# +-----------+-----+
# |SegmentType|Total|
# +-----------+-----+
# |     Custom|43241|
# |     Gender| 2676|
# |     Mobile| 2676|
# | University| 2175|
# |        Web|    2|
# +-----------+-----+

# %%
dfx.groupBy("SegmentDescription") \
  .agg(sum("Count").alias("Total")) \
  .sort(col("Total").desc()) \
  .show()
# Out:
# +--------------------+-----+
# |  SegmentDescription|Total|
# +--------------------+-----+
# |      Global results| 2676|
# |     I'm in? College| 2325|
# |    you a virgin? No| 1696|
# |closely identify ...| 1572|
# |What's your GPA? ...| 1566|
# |         Male voters| 1562|
# |clubs / organizat...| 1543|
# |student loan debt...| 1528|
# |   Mac or PC? Mac 🖥| 1457|
# |Sexual orientatio...| 1193|
# |do per month? Rea...| 1192|
# |       Female voters| 1114|
# |  Are you? Christian| 1113|
# | in Greek life? Yes!| 1082|
# |grow up speaking?...| 1045|
# |have a job? Nope,...|  927|
# |Graduation Year 2019|  844|
# |What's your leani...|  834|
# |you vote for? Hil...|  833|
# |are you pursuing?...|  794|
# +--------------------+-----+
# only showing top 20 rows

# %%
dfx.groupBy("SegmentType","Answer") \
  .agg(sum("Count").alias("Total")) \
  .sort(col("Total").desc()) \
  .show()
# Out:
# +-----------+---------+-----+
# |SegmentType|   Answer|Total|
# +-----------+---------+-----+
# |     Custom|     None|16277|
# |     Custom|Instagram|13964|
# |     Custom| Facebook| 8747|
# |     Custom|  Twitter| 2918|
# |     Custom| Snapchat| 1335|
# |     Gender|     None|  949|
# |     Mobile|     None|  947|
# |     Mobile|Instagram|  916|
# |     Gender|Instagram|  915|
# | University|     None|  761|
# | University|Instagram|  729|
# |     Gender| Facebook|  548|
# |     Mobile| Facebook|  548|
# | University| Facebook|  486|
# |     Mobile|  Twitter|  179|
# |     Gender|  Twitter|  179|
# | University|  Twitter|  131|
# |     Mobile| Snapchat|   86|
# |     Gender| Snapchat|   85|
# | University| Snapchat|   68|
# +-----------+---------+-----+
# only showing top 20 rows

# %%
dfx.groupBy("Answer","SegmentType") \
  .agg(sum("Count").alias("Total")) \
  .sort(col("Answer").desc()) \
  .show(30)
# Out:
# +---------+-----------+-----+
# |   Answer|SegmentType|Total|
# +---------+-----------+-----+
# |  Twitter|     Gender|  179|
# |  Twitter| University|  131|
# |  Twitter|     Custom| 2918|
# |  Twitter|        Web|    0|
# |  Twitter|     Mobile|  179|
# | Snapchat|     Custom| 1335|
# | Snapchat|        Web|    0|
# | Snapchat| University|   68|
# | Snapchat|     Mobile|   86|
# | Snapchat|     Gender|   85|
# |     None|     Custom|16277|
# |     None|     Gender|  949|
# |     None|     Mobile|  947|
# |     None| University|  761|
# |     None|        Web|    2|
# |Instagram|     Custom|13964|
# |Instagram| University|  729|
# |Instagram|     Gender|  915|
# |Instagram|     Mobile|  916|
# |Instagram|        Web|    0|
# | Facebook| University|  486|
# | Facebook|     Custom| 8747|
# | Facebook|        Web|    0|
# | Facebook|     Mobile|  548|
# | Facebook|     Gender|  548|
# +---------+-----------+-----+

# %%
dfx.groupBy("Answer","SegmentDescription") \
  .agg(sum("Count").alias("Total")) \
  .sort(col("Answer").desc()) \
  .show(30)
# Out:
# +-------+--------------------+-----+
# | Answer|  SegmentDescription|Total|
# +-------+--------------------+-----+
# |Twitter|Truman State Univ...|    2|
# |Twitter|grow up speaking?...|   76|
# |Twitter|Seton Hall Univer...|    1|
# |Twitter|your zodiac sign?...|   10|
# |Twitter|University of Mou...|    0|
# |Twitter|    Colorado Academy|    0|
# |Twitter|    you a virgin? No|  108|
# |Twitter|closely identify ...|    1|
# |Twitter|University of Flo...|    1|
# |Twitter|         Male voters|  122|
# |Twitter|your zodiac sign?...|    6|
# |Twitter|  University of Iowa|    1|
# |Twitter|closely identify ...|    2|
# |Twitter| Medford High School|    0|
# |Twitter|Graduation Year 2020|   47|
# |Twitter|Newcastle University|    0|
# |Twitter|What's your major...|    1|
# |Twitter|clubs / organizat...|    2|
# |Twitter|California State ...|    0|
# |Twitter|or private school...|   69|
# |Twitter|      Illinois State|    0|
# |Twitter|Santa Clara Unive...|    0|
# |Twitter|you vote for? Wri...|    8|
# |Twitter|What's your major...|   14|
# |Twitter|your zodiac sign?...|    9|
# |Twitter|Lock Haven Univer...|    0|
# |Twitter|Chaparral High Sc...|    0|
# |Twitter|University of Ari...|    5|
# |Twitter|University of Col...|    0|
# |Twitter|What's your major...|   33|
# +-------+--------------------+-----+
# only showing top 30 rows

# %%
dfx.groupBy("SegmentType","SegmentDescription") \
  .agg(sum("Count").alias("Total")) \
  .sort(col("SegmentType").desc()) \
  .show(30)
# Out:
# +-----------+--------------------+-----+
# |SegmentType|  SegmentDescription|Total|
# +-----------+--------------------+-----+
# |        Web|                 Web|    2|
# | University|   Kalamazoo College|    1|
# | University|Baltimore City Co...|    1|
# | University|   Butler University|   33|
# | University|    Arbroath Academy|    1|
# | University|Northwestern Univ...|  115|
# | University| Wesleyan University|    1|
# | University|Johns Hopkins Uni...|   12|
# | University|University of Cal...|    1|
# | University|   Baylor University|    1|
# | University|Randolph-Macon Co...|    7|
# | University|Stephen F. Austin...|    1|
# | University|University of Mis...|   24|
# | University|Indiana Universit...|    1|
# | University|United States Mil...|    1|
# | University|University of Not...|    1|
# | University|University of Cen...|    2|
# | University|West Virginia Uni...|    2|
# | University|Texas Christian U...|   23|
# | University|Saginaw Valley St...|    1|
# | University|Wake Forest Unive...|    1|
# | University|Boise State Unive...|    1|
# | University|Universidad Nacio...|    1|
# | University| Stanford University|    9|
# | University| Kutztown University|    1|
# | University|Colorado State Un...|    1|
# | University|University of Mou...|    1|
# | University| University of Texas|   38|
# | University|   Dartmouth College|   17|
# | University|Cal Poly San Luis...|    2|
# +-----------+--------------------+-----+
# only showing top 30 rows

# %%
dfx.groupBy("Answer","SegmentType","SegmentDescription") \
  .agg(sum("Count").alias("Total")) \
  .sort(col("Answer").desc()) \
  .show(30)
# Out:
# +-------+-----------+--------------------+-----+
# | Answer|SegmentType|  SegmentDescription|Total|
# +-------+-----------+--------------------+-----+
# |Twitter|     Gender|         Male voters|  122|
# |Twitter| University|Arkansas Tech Uni...|    0|
# |Twitter| University|University of Del...|    0|
# |Twitter| University|  Cornell University|    1|
# |Twitter| University|Hampden-Sydney Co...|    0|
# |Twitter| University|Seton Hall Univer...|    1|
# |Twitter|     Custom|your parents make...|   10|
# |Twitter|     Custom|your zodiac sign?...|    9|
# |Twitter| University|  Clemson University|    0|
# |Twitter| University|  Chapman University|    0|
# |Twitter| University|University of Cen...|    0|
# |Twitter|     Custom|do per month? 1 t...|   27|
# |Twitter| University|University of Min...|    0|
# |Twitter|     Custom|Sexual orientatio...|    7|
# |Twitter| University|University of Mon...|    0|
# |Twitter| University|Grand Valley Stat...|    0|
# |Twitter| University|Universidad Nacio...|    0|
# |Twitter| University|University of Wes...|    0|
# |Twitter|     Custom|What's your GPA? ...|    4|
# |Twitter| University|Cypress Creek Hig...|    0|
# |Twitter| University|Students of New York|    5|
# |Twitter|     Custom|     I'm in? College|  151|
# |Twitter| University|Binghamtom Univer...|    0|
# |Twitter|     Custom|in Greek life? Ye...|    7|
# |Twitter| University|University of Guelph|    0|
# |Twitter| University|University of Cal...|    0|
# |Twitter| University|   Dartmouth College|    1|
# |Twitter|     Custom| Mac or PC? Other 🐧|    4|
# |Twitter| University|   Baylor University|    0|
# |Twitter|     Custom|closely identify ...|    2|
# +-------+-----------+--------------------+-----+
# only showing top 30 rows

# %%
# !pip install plotly
# Out:
# WARNING: Ignoring invalid distribution -ystan (/home/niharika/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ystan (/home/niharika/anaconda3/lib/python3.9/site-packages)
# Requirement already satisfied: plotly in ./anaconda3/lib/python3.9/site-packages (5.5.0)
# Requirement already satisfied: six in ./anaconda3/lib/python3.9/site-packages (from plotly) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in ./anaconda3/lib/python3.9/site-packages (from plotly) (8.0.1)
# WARNING: Ignoring invalid distribution -ystan (/home/niharika/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ystan (/home/niharika/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -ystan (/home/niharika/anaconda3/lib/python3.9/site-packages)

# %%
datay=dfx.toPandas()

# %%
npie1=datay.groupby(["Answer"]).sum()

# %%
npie1=npie1.reset_index()

# %%
npie1.columns
# Out:
# Index(['Answer', 'Count', 'Percentage'], dtype='object')

# %%
npie1["Answer"]
# Out:
# 0     Facebook
# 1    Instagram
# 2         None
# 3     Snapchat
# 4      Twitter
# Name: Answer, dtype: object

# %%
pie1=pd.DataFrame({"Answer":npie1["Answer"],"Count":npie1["Count"]})

# %%
pie1
# Out:
#       Answer  Count
# 0   Facebook  10329
# 1  Instagram  16524
# 2       None  18936
# 3   Snapchat   1574
# 4    Twitter   3407

# %%
import plotly.express as px

# %%
fig = px.pie(pie1, values='Count', names='Answer' )

# %%
fig.show()
# Out:
# <div>                            <div id="57c97058-bd4e-430a-97df-1bcbde5a6d4c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57c97058-bd4e-430a-97df-1bcbde5a6d4c")) {                    Plotly.newPlot(                        "57c97058-bd4e-430a-97df-1bcbde5a6d4c",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Answer=%{label}<br>Count=%{value}<extra></extra>","labels":["Facebook","Instagram","None","Snapchat","Twitter"],"legendgroup":"","name":"","showlegend":true,"values":[10329,16524,18936,1574,3407],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"sca ...
#
# var gd = document.getElementById('57c97058-bd4e-430a-97df-1bcbde5a6d4c');
# var x = new MutationObserver(function

# %% [markdown]
# #### The above pie plot shows the different online platforms from where the customers are influenced for online shopping.

# %%
npie2=datay.groupby(["SegmentType"]).sum()

# %%
npie2
# Out:
#              Count  Percentage
# SegmentType
# Custom       43241     111.012
# Gender        2676       1.999
# Mobile        2676       1.000
# University    2175     173.993
# Web              2       1.000

# %%
npie2=npie2.reset_index()

# %%
npie2.columns
# Out:
# Index(['SegmentType', 'Count', 'Percentage'], dtype='object')

# %%
pie2=pd.DataFrame({"SegmentType":npie2["SegmentType"],"Count":npie2["Count"]})

# %%
fig = px.pie(pie2, values='Count', names='SegmentType' )
fig.show()
# Out:
# <div>                            <div id="2d8e0fa6-eaa0-44ae-8902-3066ef1b42c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d8e0fa6-eaa0-44ae-8902-3066ef1b42c9")) {                    Plotly.newPlot(                        "2d8e0fa6-eaa0-44ae-8902-3066ef1b42c9",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"SegmentType=%{label}<br>Count=%{value}<extra></extra>","labels":["Custom","Gender","Mobile","University","Web"],"legendgroup":"","name":"","showlegend":true,"values":[43241,2676,2676,2175,2],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3 ...
#
# var gd = document.getElementById('2d8e0fa6-eaa0-44ae-8902-3066ef1b42c9');
# var x = new MutationObserver(function (mut

# %% [markdown]
# #### From the above plot we can observe the different sectors from where the survey was performed.

# %%
fig=px.histogram(datay,x='SegmentType', color='Answer', barmode='group')
fig.show()
# Out:
# <div>                            <div id="26b72fd5-2e3e-4f57-a1b1-939d57931b05" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26b72fd5-2e3e-4f57-a1b1-939d57931b05")) {                    Plotly.newPlot(                        "26b72fd5-2e3e-4f57-a1b1-939d57931b05",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Answer=Facebook<br>SegmentType=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Facebook","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Facebook","offsetgroup":"Facebook","orientation":"v","showlegend":true,"x":["Mobile","Web","Gender","Gender","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","University","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom","Custom" ...

# %% [markdown]
# #### From the above graph we can observe the number of records on different platforms in different sectors.

# %%
fig=px.histogram(datay,x='SegmentDescription', color='Answer', barmode='group')
fig.show()
# Out:
# <div>                            <div id="bcd8f6dd-20a6-4608-bec6-4053feb1e556" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bcd8f6dd-20a6-4608-bec6-4053feb1e556")) {                    Plotly.newPlot(                        "bcd8f6dd-20a6-4608-bec6-4053feb1e556",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Answer=Facebook<br>SegmentDescription=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Facebook","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Facebook","offsetgroup":"Facebook","orientation":"v","showlegend":true,"x":["Global results","Web","Female voters","Male voters","University of Delaware","University of Pennsylvania","Students of New York","University of Central Arkansas","Northeastern University","West Virginia University ","Northern Arizona University","University of California, Santa Barbara","University of Memphis","Auburn University","Randolph-Macon College","Wisconsin HS","Penn State University","Case Western Reserve University","Rutgers University","University of Oregon","University of Toronto","State University of New York Geneso","Carthage College","University of South Carolina","Wesleyan University","Memorial University of Newfoundland","University of Kansas","University of Redlands","University of Arkansas","Richland High School","Wake Forest University","Iowa State University","Florida Gulf Coast University","University of Central Missouri","California State University Long Beach","Chaparral High School","Colorado Academy","United States Naval Academy","University of Wisconsin-Whitewater","Lock Haven University","Kalamazoo College","Stanford University","Vanderbilt University","Chapman University","Missouri State University","Emory University","University of Richmond","Medford High School","University of British Columbia","Colby College","Bates College","Westport, CT","Whitman College","Thompson Rivers University ","University of Central Florida","University of Montana ","University of Nebraska","Whatsgoodly University","Tufts University","Texas Tech University","Kansas State University","University of Notre Dame","University of Georgia","Ohio University","Washington State University","Binghamtom University","George Washington University","University of Alabama","University of Florida","The College of New Jersey","Florida State University","Santa Clara University","Appalachian State University","Arbroath Academy","Arkansas Tech University ","University of Rhode Island","Virginia Tech","Syracuse University","Cypress Creek High School","Union High School","College of William and Mary","Ohio State University","Gulf Breeze High School","Cal Poly San Luis Obispo","Oklahoma State University ","University of Texas","Hampden-Sydney College ","University of Arizona","Coventry University","Rochester Institute of Technology","Colgate University","Northwestern University","Saginaw Valley State University","University of Michigan","Boise State University","Cornell University","University of New Hampshire","UMass Dartmouth","High Point University","University of Minnesota","Claremont McKenna College","University of Central Oklahoma","Illinois State","University of Guelph","Queens University","University of Colorado Boulder","University of Virginia","Villanova University","Centre College","Johns Hopkins University","University of Wisconsin-Madison","Dartmouth College","Purdue University","San Diego State University","Michigan State University","Butler University","Indiana University","University of California, Berkeley","University of Missouri","Texas Christian University","Truman State University","University of Illinois","University of Washington","University of North Carolina","Miami University (Ohio)","University of California, ...

# %% [markdown]
# #### From the above plot we can observe the different questions enquired by customers on different platforms.
